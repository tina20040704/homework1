# %% [markdown]
# <a href="https://colab.research.google.com/github/tina20040704/homework1/blob/main/homework4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/CSV原始檔/population.csv')

with pd.ExcelWriter('output.xlsx') as writer:
    df.to_excel(writer, sheet_name='Sheet1', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('output.xlsx', sheet_name='Sheet1', usecols='A:B')


print(df)
# Out:
#      year    pop
# 0    1950   2.53
# 1    1951   2.57
# 2    1952   2.62
# 3    1953   2.67
# 4    1954   2.71
# ..    ...    ...
# 146  2096  10.81
# 147  2097  10.82
# 148  2098  10.83
# 149  2099  10.84
# 150  2100  10.85
#
# [151 rows x 2 columns]

# %%
x = df['pop']
y = df['year']

plt.plot(x, y)

plt.xlabel('pop')
plt.ylabel('year')

plt.show()

# %%
import random

data = df.groupby(['year']).sum()['pop']
colors = []

for i in range(len(data)):
    r = random.randint(0, 255)
    g = random.randint(0, 255)
    b = random.randint(0, 255)
    colors.append((r/255, g/255, b/255))

plt.pie(data,colors=colors,autopct='%1.1f%%')
plt.show()
