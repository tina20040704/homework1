# %% [markdown]
# <a href="https://colab.research.google.com/github/tina20040704/homework1/blob/main/homework5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 第一个方程的参数
a1 = -3
b1 = -4
c1 = 7

# 第二个方程的参数
a2 = 5
b2 = -4
c2 = 9

# 计算第一个方程的y值
y1 = a1 * x**2 + b1 * x + c1

# 计算第二个方程的y值
y2 = a2 * x**2 + b2 * x + c2

# 计算第一个方程的根和最大/最小值
root1_1 = (-b1 + np.sqrt(b1**2 - 4*a1*c1)) / (2*a1)
root1_2 = (-b1 - np.sqrt(b1**2 - 4*a1*c1)) / (2*a1)
extrema1 = -b1 / (2*a1)

# 计算第二个方程的根和最大/最小值
root2_1 = (-b2 + np.sqrt(b2**2 - 4*a2*c2)) / (2*a2)
root2_2 = (-b2 - np.sqrt(b2**2 - 4*a2*c2)) / (2*a2)
extrema2 = -b2 / (2*a2)

# 创建图形
plt.figure()

# 绘制第一个方程的曲线
plt.plot(x, y1, label='1')

# 绘制第二个方程的曲线
plt.plot(x, y2, label='2')

# 添加根和最大/最小值的标注
plt.annotate(f'Roots: {root1_1:.2f}, {root1_2:.2f}', xy=(root1_1, 0), xytext=(-50, -30),
             textcoords='offset points', arrowprops=dict(arrowstyle="->"))
plt.annotate(f'Extrema: {extrema1:.2f}', xy=(extrema1, a1*extrema1**2 + b1*extrema1 + c1),
             xytext=(-50, 50), textcoords='offset points', arrowprops=dict(arrowstyle="->"))

plt.annotate(f'Roots: {root2_1:.2f}, {root2_2:.2f}', xy=(root2_1, 0), xytext=(-50, -30),
             textcoords='offset points', arrowprops=dict(arrowstyle="->"))
plt.annotate(f'Extrema: {extrema2:.2f}', xy=(extrema2, a2*extrema2**2 + b2*extrema2 + c2),
             xytext=(-50, 30), textcoords='offset points', arrowprops=dict(arrowstyle="->"))

# 添加坐标轴标签
plt.xlabel('x')
plt.ylabel('y')

# 显示图形
plt.show()
# Out:
# <ipython-input-13-56924cdd8fd6>:29: RuntimeWarning: invalid value encountered in sqrt
#   root2_1 = (-b2 + np.sqrt(b2**2 - 4*a2*c2)) / (2*a2)
# <ipython-input-13-56924cdd8fd6>:30: RuntimeWarning: invalid value encountered in sqrt
#   root2_2 = (-b2 - np.sqrt(b2**2 - 4*a2*c2)) / (2*a2)
